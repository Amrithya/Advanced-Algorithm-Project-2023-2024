# %%
from branch_and_bound.branch_and_bound_non_constrainred_final import max_segment_branch_and_bound
from test_class.test_algorithm import TestAlgorithm
from visualizations.visualize_sns import create_test_result_plots
import numpy as np
import timeit

# %%
test_algorithm_instance = TestAlgorithm()

# %%
algorithm_name = "Branch and Bound  non Constrained algorithm"
test_results = test_algorithm_instance.run_algorithm_tests(max_segment_branch_and_bound,algorithm_name)
create_test_result_plots(test_results,algorithm_name)
# Out:
# TESTING Branch and Bound  non Constrained algorithm WITHOUT CONSTRAINTS
#
# ...
#
# Test Case 1 skipped: Matrix is empty.
#
# Test Case 2 skipped: Matrix contains non-numeric values.
#
# Test Case 3 skipped: Matrix is non-rectangular.
#
# Test Case 4 skipped: Matrix is non-rectangular.
#
# Test Case 5 skipped: Matrix is one-dimensional.
#
# Test Case 6 succeeded
# Result: 10
# Expected Result: 10
# Indices: (0, 0) to (1, 1)
# Expected Indices: (0, 0) to (1, 1)
# Matrix:
# [1, 2]
# [3, 4]
#
# Submatrix
# 1	2
# 3	4
#
# Time taken: 0.000242 seconds
#
#
# Test Case 7 succeeded
# Result: 8
# Expected Result: 8
# Indices: (0, 0) to (3, 1)
# Expected Indices: (0, 0) to (3, 1)
# Matrix:
# [1, 1]
# [1, 1]
# [1, 1]
# [1, 1]
#
# Submatrix
# 1	1
# 1	1
# 1	1
# 1	1
#
# Time taken: 0.000179 seconds
#
#
# Test Case 8 failed: -15 != -1
# Result: -15
# Expected Result: -1
# Indices: (1, 2) to (2, 2)
# Expected Indices: (0, 0) to (0, 0)
# Matrix:
# [-1, -2, -3]
# [-4, -5, -6]
# [-7, -8, -9]
# Submatrix:
#
# ...
