# %%
from branch_and_bound.branch_and_bound_ import max_segment_branch_and_bound
from branch_and_bound.branch_and_bound_constraint import max_segment_branch_and_bound_constraint
from test_class.test_algorithm_non_constrained import TestAlgorithm
import numpy as np
import timeit
# Out:
# C:\Users\annak\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\annak\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\annak\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
test_algorithm_instance = TestAlgorithm()

# %%
size_time, success, fail = test_algorithm_instance.run_algorithm_tests(max_segment_branch_and_bound, "Branch and Bound  non Constrained algorithm")
# Out:
# TESTING Branch and Bound  non Constrained algorithm
#
# ...
#
# Test Case 1 skipped: Input not a matrix.
#
# Test Case 2 skipped: Matrix contains non-numeric values.
#
# Test Case 3 skipped: Matrix is non-rectangular.
#
# Test Case 4 skipped: Matrix is non-rectangular.
#
# Test Case 5 skipped: Matrix is one-dimensional.
#
# Test Case 6 succeeded
# Result: 10
# Expected Result: 10
# Indices: (0, 0) to (1, 1)
# Expected Indices: (0, 0) to (1, 1)
# Matrix:
# [1, 2]
# [3, 4]
#
# Submatrix
# 1	2
# 3	4
#
# Time taken: 0.004706 seconds
#
#
# Test Case 7 succeeded
# Result: 8
# Expected Result: 8
# Indices: (0, 0) to (3, 1)
# Expected Indices: (0, 0) to (3, 1)
# Matrix:
# [1, 1]
# [1, 1]
# [1, 1]
# [1, 1]
#
# Submatrix
# 1	1
# 1	1
# 1	1
# 1	1
#
# Time taken: 0.000226 seconds
#
#
# Test Case 8 succeeded
# Result: -1
# Expected Result: -1
# Indices: (0, 0) to (0, 0)
# Expected Indices: (0, 0) to (0, 0)
# Matrix:
# [-1, -2, -3]
# [-4, -5, -6]
# [-7, -8, -9]
#
# Submatrix
# -1
#
# ...

# %%
print(success)
