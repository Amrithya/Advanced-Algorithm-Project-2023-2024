# %% [markdown]
# ## Testing of Randomized Algorithms (Constrained and Non-constrained)
#
# In this cell, we import specific algorithm functions and a test class to set up our testing environment:
# - `find_max_sum_submatrix` from the randomized approach module for unconstrained problems.
# - `random_fixed_size_submatrix_sum` for constrained problems, also from the randomized approach module.
# - `TestAlgorithm` class from the test class module, which will be used to conduct algorithm performance tests.
# - `create_test_result_plots` from the visualizations module to generate visual representations of our test results.

# %%
from randomized_approach.gradient_unconstrained import find_max_sum_submatrix
from randomized_approach.randomized_constrained import random_fixed_size_submatrix_sum
from test_class.test_algorithm import TestAlgorithm
from visualizations.visualize_sns import create_test_result_plots

# %% [markdown]
# - `numpy` is a fundamental package for scientific computing in Python, providing support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays.
# - `timeit` is a module that provides a simple way to time small bits of Python code, offering a precise mechanism to measure the execution time of our algorithms.

# %%
import numpy as np
import timeit

# %% [markdown]
# ### Test Algorithm Instance Initialization
#
# In this cell, we initialize an instance of the `TestAlgorithm` class:
# - `test_algorithm_instance` is created to facilitate the testing of various algorithmic functions imported earlier.
# - This instance will be used to run tests and evaluate the performance of different algorithms throughout the notebook.

# %%
test_algorithm_instance = TestAlgorithm()

# %% [markdown]
# # Non-Constrained Randomized Approach: Randomized Gradient Descent

# %%
algorithm_name = "Randomized Gradient Descent"
test_results = test_algorithm_instance.run_algorithm_tests(find_max_sum_submatrix,algorithm_name)
create_test_result_plots(test_results,algorithm_name)
# Out:
# TESTING Randomized Gradient Descent WITHOUT CONSTRAINTS
#
# ...
#
# Test Case 1 skipped: Matrix is empty.
#
# Test Case 2 skipped: Matrix contains non-numeric values.
#
# Test Case 3 skipped: Matrix is non-rectangular.
#
# Test Case 4 skipped: Matrix is non-rectangular.
#
# Test Case 5 skipped: Matrix is one-dimensional.
#
# Test Case 6 succeeded
# Result: 45
# Expected Result: 45
# Indices: (2, 1) to (2, 1)
# Expected Indices: (2, 1) to (2, 1)
# Matrix:
# [-81, 0]
# [20, -77]
# [-45, 45]
# [-6, -45]
#
# Submatrix
# 45
#
# Time taken: 0.234716 seconds
#
#
# Test Case 7 succeeded
# Result: 126
# Expected Result: 126
# Indices: (0, 3) to (0, 5)
# Expected Indices: (0, 3) to (0, 5)
# Matrix:
# [-89, -18, -34, 60, 53, 13]
# [12, 92, -69, -98, 28, -13]
#
# Submatrix
# 60	53	13
#
# Time taken: 0.018167 seconds
#
#
# Test Case 8 succeeded
# Result: 100
# Expected Result: 100
# Indices: (0, 0) to (2, 0)
# Expected Indices: (0, 0) to (2, 0)
# Matrix:
# [47, -44]
# [-13, 37]
# [66, 0]
# [-16, -93]
# ...

# %% [markdown]
# ## Randomized Constrained with Variable Constraints

# %%
algorithm_name = "Randomized Constrained"
test_results = test_algorithm_instance.run_algorithm_tests(random_fixed_size_submatrix_sum, algorithm_name,constrained_type='variable')
create_test_result_plots(test_results,algorithm_name)
# Out:
# TESTING Randomized Constrained WITH VARIABLE CONSTRAINTS
#
# ...
#
# Test Case 1 skipped: Matrix is empty.
#
# Test Case 2 skipped: Matrix is one-dimensional.
#
# Test Case 3 skipped: Matrix is non-rectangular.
#
# Test Case 4 skipped: Matrix is non-rectangular.
#
# Test Case 5 skipped: Constraints k or l exceed matrix dimensions.
#
# Test Case 6 skipped: Constraints k or l exceed matrix dimensions.
# Algorithm Found a different solution than the expected solution but it is the right solution
#
# Test Case 7 succeeded
# Result: 100
# Expected Result: 100
# Indices: (12, 3) to (12, 3)
# Expected Indices: (3, 12) to (3, 12)
# Matrix:
# [-80, 86, -26, -17, 32, 57, 73, -86, 63, -68, 28, -45, -19, 53, 39]
# [-48, 24, -28, 26, -12, -35, 12, -25, -10, 48, 60, -50, 12, -39, -68]
# [-92, 28, -58, 67, 46, -4, 58, -58, 14, 17, -95, -63, 72, 74, 67]
# [-21, 35, 39, -20, -30, 60, -31, -81, 84, -81, -22, -94, 100, -28, -56]
# [-44, 27, -100, -7, 49, 30, -97, 58, 74, 95, -99, -69, 76, 64, 24]
# ...

# %% [markdown]
# ## Randomized Constrained with fixed (4,5) Constraints on different Matrix Sizes

# %%
algorithm_name = "Randomized Constrained"
test_results = test_algorithm_instance.run_algorithm_tests(random_fixed_size_submatrix_sum, algorithm_name,constrained_type='fixed')
create_test_result_plots(test_results,algorithm_name)
# Out:
# TESTING Randomized Constrained WITH FIXED CONSTRAINTS
#
# ...
#
# Test Case 1 skipped: Matrix is empty.
#
# Test Case 2 skipped: Matrix is one-dimensional.
#
# Test Case 3 skipped: Matrix is non-rectangular.
#
# Test Case 4 skipped: Matrix is non-rectangular.
#
# Test Case 5 skipped: Constraints k or l exceed matrix dimensions.
#
# Test Case 6 skipped: Constraints k or l exceed matrix dimensions.
#
# Test Case 7 succeeded
# Result: 436
# Expected Result: 436
# Indices: (3, 0) to (6, 4)
# Expected Indices: (3, 0) to (6, 4)
# Matrix:
# [-91, -32, -57, 65, -69, -80]
# [-92, 80, -96, -96, 13, -95]
# [-24, 34, 51, 64, 34, 98]
# [-18, 11, -9, 94, -14, -94]
# [-13, 72, 44, 86, -97, -53]
# [-20, 1, 22, 25, 92, -51]
# [72, 51, -26, 25, 38, -53]
# [-64, 56, -76, -21, 76, 28]
#
# Submatrix
# -18	11	-9	94	-14
# -13	72	44	86	-97
# -20	1	22	25	92
# 72	51	-26	25	38
#
# Time taken: 0.008880 seconds
#
#
# Test Case 8 succeeded
# Result: 54
# Expected Result: 54
# Indices: (0, 2) to (3, 6)
# ...
